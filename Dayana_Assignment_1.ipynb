# %% [markdown]
# # PDS: Assignment 1
#
# ### Deadline: April 18 (until 23:59)
#
#
# **Instructions:** All answers should be filled in the notebook and then submitted to Moodle. For theoretical question you can use markdown and LaTeX. Name of notebook should be in following format:
#  - Name_group_Assignment_1.ipynb (ex. Bill_Gates_1905_Assignment_1.ipynb)
#  - Try to use fewer cells for compilation (for example, you can use print for several answers, instead of printing each answer on a separate cell)
#  - **PLEASE:** submit only one jupyter notebook (no zip or csv files) and with your names as in the instruction. Ohterwise, there will be punishment for 2 points.

# %% [markdown]
# ## Q1 (1 point)
# Prove the Bias-Variance tradeoff decomposition, where MSE can be written as a sum of Variance of the estimator, Bias (squared) of the estimator and an irreducible error.

# %% [markdown]
# #### ✤ As we know from lectures, the Bias-variance decomposition is extremely important, when we want to get a things like overfitting, underfitting, and model capacity.
# + Let's prove that, **MSE = Variance + Bias^2 + Error**
# + $E(y_0 - \hat{f}(x_0))^2 = Var(\hat{f}(x_0)) + [Bias(\hat{f}(x_0))]^2 + Var(\epsilon)$
#
#
# + And we know that Each variable is equal to:
# + $ Bias(\hat{f}(x_0)) = E[\hat{f}(x_0)] - f(x_0)$
# + $ Var(\hat{f}(x_0)) = E(\hat{f}(x_0)^2)- E(\hat{f}(x_0))^2 $
# + $ y =f(x_0)+ϵ  $   -> irreducible error
#
#
# + For simplicity, let's take these variables as
# + $ \hat{f}(x_0) = \hat{f}$ and $f(x_0) = f $ and $y_0 = y $

# %% [markdown]
# + ✤ To begin, I am going to substitute,  y with -> $ f+ϵ $ :
# + = **MSE **
# + = $ E[(y - \hat{f})^2] $
# + = $ E[(f + \epsilon - \hat{f})^2]  $
# + = $ E[(f + \epsilon - \hat{f} + E[\hat{f}] - E[\hat{f}])^2 ] $
# + When we open brackets, it solves like:
# + = $ E[(f- E[\hat{f}])^2] + E[\epsilon^2] + E[(E[\hat{f})]- \hat{f})^2] + 2E[(f-E[\hat{f})\epsilon] + 2E[\epsilon(E[\hat{f}]-\hat{f})] +\ 2E[(E[\hat{f}]-\hat{f})(f-E(\hat{f})] $
# + = $ (f-E[\hat{f}])^2 + E[\epsilon^2]+E[(E[\hat{f}] -\hat{f})^2]+2 (f-E[\hat{f}])E[\epsilon] + 2E[\epsilon]E[E[\hat{f}]-\ \hat{f}] + 2E[E[\hat{f}] - \hat{f}] (f-E[\hat{f}])$
# + After that I cancelled right half side,
# + = $ (f-E[\hat{f}])^2 + E[\epsilon^2]+E[(E[\hat{f}] -\hat{f})^2] $
# + = $ (f-E[\hat{f}])^2 + Var[\epsilon] + Var[\hat{f}] $
# + = $ Bias(\hat{f})^2 + Var[\epsilon] + Var[\hat{f}] $
#
#
# + ✤ Now, as I have checked the provement of MSE, we can definitely say that:
# + $ E[(y - \hat{f})^2] $ = $ Var[\epsilon]+ Bias(\hat{f})^2 + Var[\hat{f}] $
# + $E(y_0 - \hat{f}(x_0))^2 = Var(\hat{f}(x_0)) + [Bias(\hat{f}(x_0))]^2 + Var(\epsilon)$

# %% [markdown]
# ## Q2 (1 point)
# Read "tidy_data.xlsx" and make it in Tidy Data Format. Plot scatterplots for each persons test results.
#
# _There should be 6 different scatterplots for each person_
#
# _In every scatterplot there should be 25 different colors in scatterplot for each test_

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings  # do not show matching warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('tidy_data.xlsx')
data
# Out:
#           date      Name Sex  test1  test2  test3   test4  test5  test6  \
# 0   2020-05-29      Joey   M      5     74    -47  662247      1    534
# 1   2021-04-07  Chandler   M      0     80     21  431382      2    514
# 2   2021-05-06    Rachel   F      6     20     24  949910      1    371
# 3   2020-10-10      Joey   M      9     65     23   67592      3    893
# 4   2020-08-27      Ross   M      6     25    -24  176408      2    775
# ..         ...       ...  ..    ...    ...    ...     ...    ...    ...
# 495 2020-04-08    Monica   F      2     39    -18  665460      3    749
# 496 2020-12-30      Joey   M      2     50    -40  377032      1    634
# 497 2021-04-16      Joey   M      9     60     -5  819197      2    894
# 498 2020-08-25  Chandler   M      9     35      3   83029      1    734
# 499 2021-05-07    Rachel   F      9     86     -7  201231      3    458
#
#      test7  ...  test16  test17  test18  test19  test20  test21  test22  \
# ...

# %%
data['Name'].unique()
# Out:
# array(['Joey', 'Chandler', 'Rachel', 'Ross', 'Phoebe', 'Monica'],
#       dtype=object)

# %%
# Here, I changed the structure of dataset:
# Because, we had many columns for test, I combined them:
tidiest_data = pd.melt(data, id_vars=['Name','Sex','date'], var_name=['tests'], value_name="scores")
tidiest_data
# Out:
#            Name Sex       date   tests  scores
# 0          Joey   M 2020-05-29   test1       5
# 1      Chandler   M 2021-04-07   test1       0
# 2        Rachel   F 2021-05-06   test1       6
# 3          Joey   M 2020-10-10   test1       9
# 4          Ross   M 2020-08-27   test1       6
# ...         ...  ..        ...     ...     ...
# 12495    Monica   F 2020-04-08  test25      14
# 12496      Joey   M 2020-12-30  test25      61
# 12497      Joey   M 2021-04-16  test25      18
# 12498  Chandler   M 2020-08-25  test25      27
# 12499    Rachel   F 2021-05-07  test25      33
#
# [12500 rows x 5 columns]

# %%
# I decided to sort by 6 persons Names:

tidy_data = tidiest_data.sort_values(by=["Name"]).reset_index(drop=True)
tidy_data.head()
# Out:
#        Name Sex       date   tests  scores
# 0  Chandler   M 2020-08-11   test8      31
# 1  Chandler   M 2020-01-27   test6     388
# 2  Chandler   M 2020-05-06   test4  102519
# 3  Chandler   M 2020-04-26  test22     100
# 4  Chandler   M 2020-01-09   test4  598198

# %%
# Here, I was trying to show them in 1 plot, then below, there will be Scatter plots for Each person apart.
g = sns.FacetGrid(tidy_data, col="Name")
g.map(sns.scatterplot, "date", "scores", alpha=.7)

g.set_xticklabels(rotation=30)
# g.add_legend()

# %%
# In order to filter data for Student Names:
# 'Joey', 'Chandler', 'Rachel', 'Ross', 'Phoebe', 'Monica'
df1 = tidy_data[tidy_data['Name']=='Joey']
df2 = tidy_data[tidy_data['Name']=='Chandler']
df3 = tidy_data[tidy_data['Name']=='Rachel']
df4 = tidy_data[tidy_data['Name']=='Ross']
df5 = tidy_data[tidy_data['Name']=='Phoebe']
df6 = tidy_data[tidy_data['Name']=='Monica']

# %%
df1 = tidy_data[tidy_data['Name']=='Joey']

plt.figure(figsize=(9,6))

g = sns.scatterplot(x="date", y="scores",hue="tests",data = df1,s=50)

g.axes.set_title("Scatterplot of Test Scores for ~'Joey'",fontsize=17)

g.legend(bbox_to_anchor=(1.2,1), fontsize=9.5)

g.set_xlabel("Dates of tests",fontsize=14)
g.set_ylabel("Scores range",fontsize=14)
g.tick_params(labelsize=10,rotation=30)

# %%
df2 = tidy_data[tidy_data['Name']=='Chandler']

plt.figure(figsize=(9,6))

g = sns.scatterplot(x="date", y="scores",hue="tests",data = df2,s=50)

g.axes.set_title("Scatterplot of Test Scores for ~'Chandler'",fontsize=17)

g.legend(bbox_to_anchor=(1.2,1), fontsize=9.5)

g.set_xlabel("Dates of tests",fontsize=14)
g.set_ylabel("Scores range",fontsize=14)
g.tick_params(labelsize=10,rotation=30)

# %%
df3 = tidy_data[tidy_data['Name']=='Rachel']
plt.figure(figsize=(9,6))

g = sns.scatterplot(x="date", y="scores",hue="tests",data = df3,s=50)

g.axes.set_title("Scatterplot of Test Scores for ~'Rachel'",fontsize=17)

g.legend(bbox_to_anchor=(1.2,1), fontsize=9.5)

g.set_xlabel("Dates of tests",fontsize=14)
g.set_ylabel("Scores range",fontsize=14)
g.tick_params(labelsize=10,rotation=30)

# %%
df4 = tidy_data[tidy_data['Name']=='Ross']
plt.figure(figsize=(9,6))

g = sns.scatterplot(x="date", y="scores",hue="tests",data = df4,s=50)

g.axes.set_title("Scatterplot of Test Scores for ~'Ross'",fontsize=17)

g.legend(bbox_to_anchor=(1.2,1), fontsize=9.5)

g.set_xlabel("Dates of tests",fontsize=14)
g.set_ylabel("Scores range",fontsize=14)
g.tick_params(labelsize=10,rotation=30)

# %%
df5 = tidy_data[tidy_data['Name']=='Phoebe']
plt.figure(figsize=(9,6))

g = sns.scatterplot(x="date", y="scores",hue="tests",data = df5,s=50)

g.axes.set_title("Scatterplot of Test Scores for ~'Phoebe'",fontsize=17)

g.legend(bbox_to_anchor=(1.2,1), fontsize=9.5)

g.set_xlabel("Dates of tests",fontsize=14)
g.set_ylabel("Scores range",fontsize=14)
g.tick_params(labelsize=10,rotation=30)

# %%
df6 = tidy_data[tidy_data['Name']=='Monica']

plt.figure(figsize=(9,6))

g = sns.scatterplot(x="date", y="scores",hue="tests",data = df6,s=50)

g.axes.set_title("Scatterplot of Test Scores for ~'Monica'",fontsize=17)

g.legend(bbox_to_anchor=(1.2,1), fontsize=9.5)

g.set_xlabel("Dates of tests",fontsize=14)
g.set_ylabel("Scores range",fontsize=14)
g.tick_params(labelsize=10,rotation=30)

# %% [markdown]
# + As we can see, from scatter plots each person has high scores on specific tests numbers, all tests are differnet colors.

# %% [markdown]
# ## Q3 (1 point)
# - read netflix data
# - find ratios of Movies and TV Shows for different countries
# - plot histogram of average duration length for movies with following genres: "dramas", "comedies", "sports movies" (for this case use only first genre)
# - create pivot table with count of word "love" in description for different genres (for this case use only first genre)

# %%
data2 = pd.read_csv('netflix_titles.csv')
data2.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
# print(data2.isnull().any())
# data2 = data2.dropna() 
# data2.shape

# %%
data2.describe(include='all').head(4)
# Out:
#        show_id   type         title                director  \
# count     7787   7787          7787                    5398
# unique    7787      2          7787                    4049
# top       s181  Movie  Glitch Techs  Raúl Campos, Jan Suter
# freq         1   5377             1                      18
#
#                       cast        country       date_added  release_year  \
# count                 7069           7280             7777        7787.0
# unique                6831            681             1565           NaN
# top     David Attenborough  United States  January 1, 2020           NaN
# freq                    18           2555              118           NaN
#
#        rating  duration      listed_in  \
# count    7780      7787           7787
# unique     14       216            492
# top     TV-MA  1 Season  Documentaries
# freq     2863      1608            334
#
#                                               description
# ...

# %% [markdown]
# ### ✤ Find ratios of Movies and TV Shows for different countries

# %%
# I was tryna to make ratio of Movies and Tvshows for 'Country' column:
df_2 = (pd.crosstab(data2['type'], data2['country'], normalize='index').mul(100).reset_index().rename_axis(None, axis=1))
df_2
# Out:
#       type  Argentina  Argentina, Brazil, France, Poland, Germany, Denmark  \
# 0    Movie   0.660579                                           0.019429
# 1  TV Show   0.750117                                           0.000000
#
#    Argentina, Chile  Argentina, Chile, Peru  Argentina, France  \
# 0          0.019429                0.019429           0.019429
# 1          0.000000                0.000000           0.000000
#
#    Argentina, France, United States, Germany, Qatar  Argentina, Italy  \
# 0                                          0.019429          0.019429
# 1                                          0.000000          0.000000
#
#    Argentina, Spain  Argentina, United States  ...  \
# 0          0.136002                  0.019429  ...
# 1          0.046882                  0.000000  ...
#
#    Uruguay, Argentina, Germany, Spain  Uruguay, Argentina, Spain  \
# 0                            0.019429                   0.019429
# ...

# %%
countries = data2['country'].value_counts()[data2['country'].value_counts(normalize=True)> 0.005]
list_countries = list(countries.index)

fig, ax = plt.subplots(figsize=(8,6))
ax.pie(countries.values, labels=countries.index, autopct='%1.1f%%', shadow=True)
plt.tick_params(labelsize=7)
plt.show()
# not correct chart.

# %% [markdown]
# **Initially, we can see that there are some countries are doubled, or in pairs. That's why I created new dataset and encoded  from a list of Different countries:**

# %%
# splitting dataset
country = data2.loc[data2.country.notnull(),'country'].astype('str').apply(lambda t: t.split(', '))
country = list(country)

# using preprocessing library, to split each country by show_id:
from mlxtend.preprocessing import TransactionEncoder
encoder = TransactionEncoder().fit(country)
each_count = encoder.transform(country)

each_count = pd.DataFrame(each_count,columns = encoder.columns_,index=data2.loc[data2.country.notnull(),'show_id'])

# Showing encoded dataset:
each_count.head()
# Out:
#          Afghanistan  Albania  Algeria  Angola  Argentina  Armenia  Australia  \
# show_id
# s1             False    False    False   False      False    False      False
# s2             False    False    False   False      False    False      False
# s3             False    False    False   False      False    False      False
# s4             False    False    False   False      False    False      False
# s5             False    False    False   False      False    False      False
#
#          Austria  Azerbaijan  Bahamas  ...  United Kingdom  United Kingdom,  \
# show_id                                ...
# s1         False       False    False  ...           False            False
# s2         False       False    False  ...           False            False
# s3         False       False    False  ...           False            False
# s4         False       False    False  ...           False            False
# ...

# %%
country_ratio = each_count.mean().sort_values(ascending=False).round(4) * 100
# getting countries, which produced more than 1%
country_ratio = country_ratio[country_ratio > 1]

labels = country_ratio.round(3).astype('str')+' %'

fig1, ax1 = plt.subplots(figsize=(15,10), facecolor='white')
ax1.pie(country_ratio,labels=labels, labeldistance=1.15,shadow=True,textprops={'fontsize': 14,'fontweight':'bold'})

plt.title('Ratio of produced Movies/TV Show by Each Country', fontsize=20)
plt.legend(bbox_to_anchor=(1.3,0.5),labels=country_ratio.index, loc='right',fontsize=10)

plt.show()

# %% [markdown]
# ### ✤  Plot histogram of average duration length for movies with following genres: "dramas", "comedies", "sports movies" (for this case use only first genre)

# %%
# Firstly, we should create a new column in order to take only first genre from 'listed_in' column:
data2['genre'] = data2['listed_in'].apply(lambda x: x.split(',')[0])
data2.head(3)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 cast    country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          description                   genre
# ...

# %%
data2.shape
# Out:
# (7787, 13)

# %% [markdown]
# + **Before that, as we can see from the graph, there are duration values written as 'Min' or 'Seasons'.**
# + **As we need to use only Movies, I checked that Movies duration are in Minutes, and cleaned them:**

# %%
# taking only type = MOVIES:
df_1 = data2[data2['type']=='Movie']

# as an examle 1 row of duration:
df_1['duration'][1]
# Out:
# '93 min'

# %%
# cleaning of duration column- taking only first value- Number:
df_1['duration'] = df_1['duration'].apply(lambda x: x.split(' ')[0])
#converting to integer:
df_1['duration'] = pd.to_numeric(df_1['duration'])
df_1.head(3)
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
# 3      s4  Movie      9        Shane Acker
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#           date_added  release_year rating  duration  \
# 1  December 23, 2016          2016  TV-MA        93
# 2  December 20, 2018          2011      R        78
# 3  November 16, 2017          2009  PG-13        80
#
#                                            listed_in  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          description               genre
# ...

# %%
# checking datatype of duration:
df_1['duration'].dtypes
# Out:
# dtype('int64')

# %%
# I will need -'Dramas','Comedies','Sports Movies'
df_1['genre'].unique()
# Out:
# array(['Dramas', 'Horror Movies', 'Action & Adventure', 'Documentaries',
#        'Independent Movies', 'Comedies', 'Sports Movies', 'Movies',
#        'International Movies', 'Sci-Fi & Fantasy',
#        'Children & Family Movies', 'Classic Movies', 'Thrillers',
#        'Stand-Up Comedy', 'Anime Features', 'Music & Musicals',
#        'Cult Movies', 'Romantic Movies', 'LGBTQ Movies'], dtype=object)

# %%
#PLOTTING MY HISTOGRAM-drama:

df_1_hist = df_1[df_1['genre']=='Dramas']
drama_dur = df_1_hist.duration

plt.hist(drama_dur, bins=25, color='c', edgecolor='k', alpha=0.65)
plt.axvline(drama_dur.mean(), color='k', linestyle='dashed', linewidth=1)

min_ylim, max_ylim = plt.ylim()
plt.text(drama_dur.mean()*1.1,max_ylim*0.9,'Mean: {:.2f}'.format(drama_dur.mean()),weight='bold')

plt.title('~Duration of Movies for Dramas genre~', fontsize=18)
plt.xlabel("Duration in minutes", labelpad=15,weight='bold',size=12)
plt.ylabel("Count", labelpad=15,weight='bold',size=12)
# Out:
# Text(0, 0.5, 'Count')

# %%
df_2_hist = df_1[df_1['genre']=='Comedies']
comedy_dur = df_2_hist.duration

plt.hist(comedy_dur, bins=25, color='orange', edgecolor='k', alpha=0.65)
plt.axvline(comedy_dur.mean(), color='k', linestyle='dashed', linewidth=1)

min_ylim, max_ylim = plt.ylim()
plt.text(comedy_dur.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(comedy_dur.mean()),weight='bold')

plt.title('~Duration of Movies for Comedies genre~', fontsize=18)
plt.xlabel("Duration in minutes", labelpad=15,weight='bold',size=12)
plt.ylabel("Count", labelpad=15,weight='bold',size=12)
# Out:
# Text(0, 0.5, 'Count')

# %%
df_3_hist = df_1[df_1['genre']=='Sports Movies']
sport_dur = df_3_hist.duration


plt.hist(sport_dur, bins=10, color='g', edgecolor='k', alpha=0.65)
plt.axvline(sport_dur.mean(), color='k', linestyle='dashed', linewidth=1)

min_ylim, max_ylim = plt.ylim()
plt.text(sport_dur.mean()*1.1,max_ylim*0.9,'Mean: {:.2f}'.format(sport_dur.mean()),weight='bold')

plt.title('~Duration of Movies for Sport ~', fontsize=18)
plt.xlabel("Duration in minutes", labelpad=15,weight='bold',size=12)
plt.ylabel("Count", labelpad=15,weight='bold',size=12)

# Sorry, here something get wrong.graph is too small, below is correct one:
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.title('~Duration of Movies for Sport ~', fontsize=18)
plt.xlabel("Duration in minutes", labelpad=15,weight='bold',size=12)
plt.ylabel("Count", labelpad=15,weight='bold',size=12)

plt.hist(sport_dur, bins=20)
plt.show()

# %% [markdown]
# ### ✤  create pivot table with count of word "love" in description for different genres (for this case use only first genre)

# %%
data2 = pd.read_csv('netflix_titles.csv')

# %%
data2["word"] = data2["description"].apply(lambda x: len([a for a in x.lower().split() if a =='love'])) 

genres = []
for genre in data2["listed_in"].unique():
    if type(genre)==str:
        genres.append(genre)
string = ""

# %%
for genre in genres[1:]:
    string = string + ", " + genre
string = genres[0] + string
genres = sorted(set(map(lambda x: x[:-1] if x[-1]==',' else x, list(set(string.split(", "))))))

love_df = pd.DataFrame()
love_df["genre"] = genres
love_df["word"] = None

# %%
# foing through the loop:
for i in range(len(love_df)):
    love_df.iloc[i, 1] = sum(data2[(data2["listed_in"].str.contains(love_df.iloc[i, 0]))]["word"])
    
pd.pivot_table(love_df, values='word', index=['genre'], aggfunc=np.sum).head(10)
# Out:
#                           word
# genre
# Action & Adventure          16
# Anime Features               2
# Anime Series                 1
# British TV Shows             0
# Children & Family Movies    12
# Classic & Cult TV            2
# Classic Movies               3
# Comedies                    97
# Crime TV Shows               6
# Cult Movies                  2

# %%
# data2['love'] = data2['description'].apply(lambda x: 1 if 'love' in x.lower() else 0)
# data2['love'].value_counts()
# pd.pivot_table(data2, index = ['genre', 'love'], values = 'duration', aggfunc=[ 'count'])

# %% [markdown]
# ## Q4 (2 points)
# - read "knn_bias_variance_tradeoff.csv" file
# - split your data into train and test samples with test_size = 0.3
# - create bias variance tradeoff plot of accuracy of your KNN model for train and test
# - normalize (use algorithm of your choice) your entire data, and then split your data into train and test samples with test_size = 0.3
# - based on normalized data create bias variance tradeoff plot of accuracy of your KNN model for train and test
# - try to use auc metrics instead of accuracy, and then create bias variance tradeoff plot
# - make conclusions of your findings (which data outputs clear bias variance tradeoff plot, which accuracy outputs clear bias variance tradeoff plot, etc.)

# %%
data3 = pd.read_csv('knn_bias_variance_tradeoff.csv')
data3.head()
# Out:
#           XVPM         GWYH         TRAT        TLLZ         IGGA  \
# 0  1636.670614   817.988525  2565.995189  358.347163   550.417491
# 1  1013.402760   577.587332  2644.141273  280.428203  1161.873391
# 2  1300.035501   820.518697  2025.854469  525.562292   922.206261
# 3  1059.347542  1066.866418   612.000041  480.827789   419.467495
# 4  1018.340526  1313.679056   950.622661  724.742174   843.065903
#
#           HYKR         EDFS        GUUB         MGJM         JHZC  \
# 0  1618.870897  2147.641254  330.727893  1494.878631   845.136088
# 1  2084.107872   853.404981  447.157619  1193.032521   861.081809
# 2  2552.355407   818.676686  845.491492  1968.367513  1647.186291
# 3   685.666983   852.867810  341.664784  1154.391368  1450.935357
# 4  1370.554164   905.469453  658.118202   539.459350  1899.850792
#
#    TARGET CLASS
# 0             0
# 1             1
# 2             1
# 3             0
# 4             0

# %%
data3.shape
# Out:
# (1000, 11)

# %%
data3.columns
# Out:
# Index(['XVPM', 'GWYH', 'TRAT', 'TLLZ', 'IGGA', 'HYKR', 'EDFS', 'GUUB', 'MGJM',
#        'JHZC', 'TARGET CLASS'],
#       dtype='object')

# %% [markdown]
# ### ✤ Train and Test Split - Ratio 70 / 30
# + Now let's split the data into a training set and a testing set. We'll train out model on the training set and then use the test set to evaluate the model. To do that, we need to import the following:

# %%
# importing library:
from sklearn.model_selection import train_test_split

# X and y arrays:
X = data3.drop("TARGET CLASS", axis = 1) # All columns except this column.
y = data3["TARGET CLASS"] # Only this column

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# ✤ **Create bias variance tradeoff plot of accuracy of your KNN model for train and test**

# %%
from sklearn.neighbors import KNeighborsClassifier

error = []

for i in range(1,50):
    knn_model = KNeighborsClassifier(n_neighbors = i)
    knn_model.fit(X_train, y_train)
    pred = knn_model.predict(X_test)
    error.append(np.mean(pred != y_test))
            
plt.figure(figsize=(9,5))
plt.plot(range(1, 50), error, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
plt.title('Error_Rate vs. K - Value')
plt.xlabel('K')
plt.ylabel('Error_Rate')
# Out:
# Text(0, 0.5, 'Error_Rate')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

model = KNeighborsClassifier(n_neighbors= 10)

model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[128,  18],
#        [ 41, 113]], dtype=int64)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81       146
#            1       0.86      0.73      0.79       154
#
#     accuracy                           0.80       300
#    macro avg       0.81      0.81      0.80       300
# weighted avg       0.81      0.80      0.80       300

# %%
knn = KNeighborsClassifier(n_neighbors = 10)

#fitting my knn model:
knn.fit(X_train,y_train)

knn.score(X_test,y_test)
# Out:
# 0.8033333333333333

# %%
# here I was tryna to use auc metrics

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train,y_train)

y_scores = knn.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, y_scores[:, 1])
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of kNN')
plt.show()

# %% [markdown]
# ### Now, let's normalize my data3 and create knn model:

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
data_df = ss.fit_transform(data3)

# X and y arrays:
# X = data_df.drop("TARGET CLASS", axis = 1) # All columns except this column.
# y = data_df["TARGET CLASS"] # Only this column

# splitting data into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3) # 70% training and 30% test

# %%
train_score = []
test_score = []
k_vals = []

for k in range(1, 11):
    k_vals.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    
    tr_score = knn.score(X_train, y_train)
    train_score.append(tr_score)
    
    te_score = knn.score(X_test, y_test)
    test_score.append(te_score)

# %%
plt.figure(figsize=(10,5))
plt.xlabel('~~~Different Values of K')
plt.ylabel('~~~Model score')

plt.plot(k_vals, train_score, color ='fuchsia', label = "training score")
plt.plot(k_vals, test_score, color = 'green', label = 'test score')
plt.legend(bbox_to_anchor=(1, 1),bbox_transform=plt.gcf().transFigure)
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors = 10)

#fitting my knn model:
knn.fit(X_train,y_train)

knn.score(X_test,y_test)
# Out:
# 0.8233333333333334

# %%
# here I was tryna to use auc metrics

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train,y_train)

y_scores = knn.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, y_scores[:, 1])
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of kNN')
plt.show()

# %%
 #  from sklearn.neighbors import KNeighborsClassifier
 #  from mlxtend.evaluate import bias_variance_decomp

    # model = KNeighborsClassifier()

    # Now estimate bias and variance

    # mse, bias, var = bias_variance_decomp(model, X_train, y_train, X_test, y_test, loss='mse', num_rounds=200, random_seed=1)
    # print('MSE: %.3f' % mse)
    # print('Bias: %.3f' % bias)
    # print('Variance: %.3f' % var)

 #  X = data3.drop("TARGET CLASS", axis = 1) # All columns except this column.
 #  y = data3["TARGET CLASS"] # Only this column

 #  X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

 #  bias_knn, var_knn, error_knn = [], [], []
 #  for k in range(1, 15):
 #      clf_knn = KNeighborsRegressor(n_neighbors=k)
 #      avg_expected_loss, avg_bias, avg_var  = avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(clf_knn, X_train, y_train, X_test, y_test, loss='mse', random_seed=123)
 #      bias_knn.append(avg_bias)
 #      var_knn.append(avg_var)
 #      error_knn.append(avg_expected_loss)
 #  plt.plot(range(1,15), error_knn, 'b', label = 'total_error')
 #  plt.plot(range(1,15), bias_knn, 'k', label = 'bias')
 #  plt.plot(range(1,15), var_knn, 'y', label = 'variance')
 #  plt.legend()

# %% [markdown]
# ##  Conclusion
# + I think that According to Knn score(first_score), I was changing the kneighbors value,like 1 ,10, and I understand that as k is larger then training and testing score becomes smaller.
# + As a greater number of neighbors are deciding the output it leads to a my model with lower variance and higher bias.

# %% [markdown]
# ---
#
# ### Evaluation
#
# | Question | Mark     | Comment
# |:-------:|:--------:|:----------------------
# | 1       |   1/1    |
# | 2       |   1/1    |
# | 3       |   1/1    |
# | 4       |   1.5/2    |
# |**Total**|**4.5/5**  |
